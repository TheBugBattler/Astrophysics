# %% [markdown]
# <a href="https://colab.research.google.com/github/TheBugBattler/Astrophysics/blob/main/Zoobot_Finetune_PyTorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import logging

logging.basicConfig(level=logging.INFO)

# %% [markdown]
# This notebook demonstrates finetuning Zoobot.
#
# Finetuning means adapting a model pretrained on a large amount of data (here, many Galaxy Zoo answers) to solve a new problem using a small amount of new data.
#
# We follow these steps:
# - Install Zoobot (PyTorch version)
# - Downloads a pretrained checkpoint
# - Download the data to finetune on, starting from that checkpoint and the data to finetune on (ring images and ring label catalog)
# - Configure and run the finetuning
#
# For standalone script examples, see zoobot/pytorch/examples/finetuning

# %% [markdown]
# ---
#
#
#
# *Retraining will be quite slow unless you use a GPU. Use the top
# toolbar: Runtime- > Change Runtime -> GPU*
#
# ---

# %% [markdown]
# ## Install Zoobot

# %%
# !git clone https://github.com/mwalmsley/zoobot.git # places the cloned repo into zoobot_dir

# there's an identical notebook I use for testing the pre-release versions of zoobot and galaxy-datasets here, if useful
# https://colab.research.google.com/drive/1A_-M3Sz5maQmyfW2A7rEu-g_Zi0RMGz5?usp=sharing
# Out:
# fatal: destination path 'zoobot' already exists and is not an empty directory.

# %%
# !pip install -e /content/zoobot[pytorch_colab]
# Out:
# Obtaining file:///content/zoobot
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from zoobot==1.0.5) (3.9.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from zoobot==1.0.5) (4.66.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from zoobot==1.0.5) (9.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from zoobot==1.0.5) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from zoobot==1.0.5) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from zoobot==1.0.5) (1.11.4)
# Requirement already satisfied: astropy in /usr/local/lib/python3.10/dist-packages (from zoobot==1.0.5) (5.3.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from zoobot==1.0.5) (1.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from zoobot==1.0.5) (3.7.1)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from zoobot==1.0.5) (14.0.2)
# Collecting wandb (from zoobot==1.0.5)
#   Downloading wandb-0.16.5-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from zoobot==1.0.5) (67.7.2)
# Collecting galaxy-datasets>=0.0.15 (from zoobot==1.0.5)
#   Downloading galaxy_datasets-0.0.17-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 7.5 MB/s eta 0:00:00
# Collecting pytorch-lightning>=2.0.0 (from zoobot==1.0.5)
#   Downloading pytorch_lightning-2.2.1-py3-none-any.whl (801 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 801.6/801.6 kB 62.8 MB/s eta 0:00:00
# Requirement already satisfied: albumentations in /usr/local/lib/python3.10/dist-packages (from zoobot==1.0.5) (1.3.1)
# Collecting pyro-ppl>=1.8.0 (from zoobot==1.0.5)
#   Downloading pyro_ppl-1.9.0-py3-none-any.whl (745 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 745.2/745.2 kB 63.5 MB/s eta 0:00:00
# Collecting torchmetrics==0.11.0 (from zoobot==1.0.5)
#   Downloading torchmetrics-0.11.0-py3-none-any.whl (512 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.4/512.4 kB 50.4 MB/s eta 0:00:00
# Collecting timm==0.6.12 (from zoobot==1.0.5)
#   Downloading timm-0.6.12-py3-none-any.whl (549 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 kB 53.3 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from timm==0.6.12->zoobot==1.0.5) (2.2.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm==0.6.12->zoobot==1.0.5) (0.17.1+cu121)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm==0.6.12->zoobot==1.0.5) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from timm==0.6.12->zoobot==1.0.5) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from torchmetrics==0.11.0->zoobot==1.0.5) (24.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from galaxy-datasets>=0.0.15->zoobot==1.0.5) (2.31.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from pyro-ppl>=1.8.0->zoobot==1.0.5) (3.3.0)
# Collecting pyro-api>=0.1.1 (from pyro-ppl>=1.8.0->zoobot==1.0.5)
#   Downloading pyro_api-0.1.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: fsspec[http]>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=2.0.0->zoobot==1.0.5) (2023.6.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=2.0.0->zoobot==1.0.5) (4.10.0)
# Collecting lightning-utilities>=0.8.0 (from pytorch-lightning>=2.0.0->zoobot==1.0.5)
#   Downloading lightning_utilities-0.11.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->zoobot==1.0.5) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->zoobot==1.0.5) (3.4.0)
# Requirement already satisfied: scikit-image>=0.16.1 in /usr/local/lib/python3.10/dist-packages (from albumentations->zoobot==1.0.5) (0.19.3)
# Requirement already satisfied: qudida>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from albumentations->zoobot==1.0.5) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from albumentations->zoobot==1.0.5) (4.9.0.80)
# Requirement already satisfied: pyerfa>=2.0 in /usr/local/lib/python3.10/dist-packages (from astropy->zoobot==1.0.5) (2.0.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->zoobot==1.0.5) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->zoobot==1.0.5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->zoobot==1.0.5) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->zoobot==1.0.5) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->zoobot==1.0.5) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->zoobot==1.0.5) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->zoobot==1.0.5) (2023.4)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb->zoobot==1.0.5) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb->zoobot==1.0.5)
#   Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 22.6 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->zoobot==1.0.5) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb->zoobot==1.0.5)
#   Downloading sentry_sdk-1.44.0-py2.py3-none-any.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.9/264.9 kB 27.9 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb->zoobot==1.0.5)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting setproctitle (from wandb->zoobot==1.0.5)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb->zoobot==1.0.5) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb->zoobot==1.0.5) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb->zoobot==1.0.5) (1.16.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->zoobot==1.0.5) (3.9.3)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb->zoobot==1.0.5)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->galaxy-datasets>=0.0.15->zoobot==1.0.5) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->galaxy-datasets>=0.0.15->zoobot==1.0.5) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->galaxy-datasets>=0.0.15->zoobot==1.0.5) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->galaxy-datasets>=0.0.15->zoobot==1.0.5) (2024.2.2)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations->zoobot==1.0.5) (3.2.1)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations->zoobot==1.0.5) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations->zoobot==1.0.5) (2024.2.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations->zoobot==1.0.5) (1.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.6.12->zoobot==1.0.5) (3.13.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.6.12->zoobot==1.0.5) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.6.12->zoobot==1.0.5) (3.1.3)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.7->timm==0.6.12->zoobot==1.0.5)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 28.3 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.7->timm==0.6.12->zoobot==1.0.5)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 68.3 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.7->timm==0.6.12->zoobot==1.0.5)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 45.8 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.7->timm==0.6.12->zoobot==1.0.5)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.5 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.7->timm==0.6.12->zoobot==1.0.5)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.5 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.7->timm==0.6.12->zoobot==1.0.5)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 2.5 MB/s eta 0:00:00
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/nvidia-curand-cu12/
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.7->timm==0.6.12->zoobot==1.0.5)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 2.6 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.7->timm==0.6.12->zoobot==1.0.5)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 1.3 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.7->timm==0.6.12->zoobot==1.0.5)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.1 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.7->timm==0.6.12->zoobot==1.0.5)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 2.6 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.7->timm==0.6.12->zoobot==1.0.5)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.6.12->zoobot==1.0.5) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.7->timm==0.6.12->zoobot==1.0.5)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->zoobot==1.0.5) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->zoobot==1.0.5) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->zoobot==1.0.5) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->zoobot==1.0.5) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->zoobot==1.0.5) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->zoobot==1.0.5) (4.0.3)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->zoobot==1.0.5)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7->timm==0.6.12->zoobot==1.0.5) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7->timm==0.6.12->zoobot==1.0.5) (1.3.0)
# Building wheels for collected packages: zoobot
#   Building editable for zoobot (pyproject.toml) ... done
#   Created wheel for zoobot: filename=zoobot-1.0.5-0.editable-py3-none-any.whl size=20380 sha256=6765b8ba8b7aec754561ef374e6cee0deb91cf42899ef9d5f984222f4c9816c1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-o63sl7su/wheels/b8/32/e8/b630fb8c4ddc2b98bfdc0c6454a7b0264bd72d5b00449d0d0f
# Successfully built zoobot
# Installing collected packages: pyro-api, smmap, setproctitle, sentry-sdk, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lightning-utilities, docker-pycreds, nvidia-cusparse-cu12, nvidia-cudnn-cu12, gitdb, nvidia-cusolver-cu12, GitPython, galaxy-datasets, wandb, zoobot, torchmetrics, pyro-ppl, timm, pytorch-lightning
# Successfully installed GitPython-3.1.43 docker-pycreds-0.4.0 galaxy-datasets-0.0.17 gitdb-4.0.11 lightning-utilities-0.11.2 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 pyro-api-0.1.2 pyro-ppl-1.9.0 pytorch-lightning-2.2.1 sentry-sdk-1.44.0 setproctitle-1.3.3 smmap-5.0.1 timm-0.6.12 torchmetrics-0.11.0 wandb-0.16.5 zoobot-1.0.5

# %% [markdown]
# If you will get the error below later:
# > AttributeError: module 'pkg_resources._vendor.packaging' has no attribute 'requirements'
#
# then restart the runtime and run it again - press the button just above.

# %%
# google colab needs this hack to make git-cloned packaged importable
# it's not needed locally
import os
import sys
zoobot_dir = '/content/zoobot'
os.chdir(zoobot_dir)
sys.path.append(zoobot_dir)
# !git pull  # just to make sure we're up to date
# Out:
# Already up to date.

# %% [markdown]
# Now we're set up and can start using Zoobot.

# %% [markdown]
# ## Download Pretrained Checkpoint

# %%
# make a directory to place the checkpoint
# this could be anywhere, but Zoobot has this folder already
checkpoint_dir = os.path.join(zoobot_dir, 'data/pretrained_models/pytorch')  # Can place your checkpoint anywhere,

# if not os.path.isdir(checkpoint_dir):
#   os.makedirs(checkpoint_dir)

# %% [markdown]
# Download the pretrained model checkpoint from Dropbox.
#
# The pretrained models are described and linked from the [Data Notes](https://zoobot.readthedocs.io/en/latest/data_notes.html) docs.
#
# Outside Colab, you can just download them with a browser.
# On Colab, we don't have a file browser, so we have will download them with this one-liner.

# %%
# !wget --no-check-certificate 'https://dl.dropboxusercontent.com/s/7ixwo59imjfz4ay/effnetb0_greyscale_224px.ckpt?dl=0' -O $checkpoint_dir/checkpoint.ckpt
# Out:
# --2024-04-01 19:44:04--  https://dl.dropboxusercontent.com/s/7ixwo59imjfz4ay/effnetb0_greyscale_224px.ckpt?dl=0
# Resolving dl.dropboxusercontent.com (dl.dropboxusercontent.com)... 162.125.4.15, 2620:100:6018:15::a27d:30f
# Connecting to dl.dropboxusercontent.com (dl.dropboxusercontent.com)|162.125.4.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17384753 (17M) [application/octet-stream]
# Saving to: ‘/content/zoobot/data/pretrained_models/pytorch/checkpoint.ckpt’
#
# /content/zoobot/dat 100%[===================>]  16.58M  32.2MB/s    in 0.5s
#
# 2024-04-01 19:44:06 (32.2 MB/s) - ‘/content/zoobot/data/pretrained_models/pytorch/checkpoint.ckpt’ saved [17384753/17384753]

# %% [markdown]
# ## Download Catalogs of Images and Labels
#
# Each catalog should be a dataframe with columns of "id_str", "file_loc", and any labels.
#
# Here I'm using galaxy-datasets to download some premade data - check it out for examples.

# %%
# galaxy-datasets is a dependency of Zoobot.
# It has code handling downloading and loading data.
from galaxy_datasets import demo_rings

# %%
data_dir = os.path.join(zoobot_dir, 'data/demo_rings')

# %%
train_catalog, label_cols = demo_rings(root=data_dir, download=True, train=True)
test_catalog, _ = demo_rings(root=data_dir, download=True, train=False)
# Out:
# Downloading https://dl.dropboxusercontent.com/s/4cfb9xbnlkvbkv1/demo_rings_train_catalog.parquet to /content/zoobot/data/demo_rings/demo_rings_train_catalog.parquet
# 100%|██████████| 30797/30797 [00:00<00:00, 845410.63it/s]
# Downloading https://dl.dropboxusercontent.com/s/xghqujm41ujjlko/demo_rings_test_catalog.parquet to /content/zoobot/data/demo_rings/demo_rings_test_catalog.parquet
# 100%|██████████| 10802/10802 [00:00<00:00, 11028936.66it/s]
# Downloading https://dl.dropboxusercontent.com/s/80s5j6dygtw0gu6/demo_rings_images.tar.gz to /content/zoobot/data/demo_rings/demo_rings_images.tar.gz
# 100%|██████████| 43446358/43446358 [00:01<00:00, 37388772.85it/s]
# Extracting /content/zoobot/data/demo_rings/demo_rings_images.tar.gz to /content/zoobot/data/demo_rings
# Using downloaded and verified file: /content/zoobot/data/demo_rings/demo_rings_train_catalog.parquet
# Using downloaded and verified file: /content/zoobot/data/demo_rings/demo_rings_test_catalog.parquet
# Using downloaded and verified file: /content/zoobot/data/demo_rings/demo_rings_images.tar.gz
# Extracting /content/zoobot/data/demo_rings/demo_rings_images.tar.gz to /content/zoobot/data/demo_rings

# %%
train_catalog.head()
# Out:
#         id_str  ring_fraction subfolder         filename  ring  \
# 0  487483_3522       0.714286    487483  487483_3522.jpg  True
# 1  287521_2026       0.666667    287521  287521_2026.jpg  True
# 2   519986_112       0.583333    519986   519986_112.jpg  True
# 3  362959_3369       0.800000    362959  362959_3369.jpg  True
# 4  426137_3385       0.700000    426137  426137_3385.jpg  True
#
#                                             file_loc
# 0  /content/zoobot/data/demo_rings/images/487483/...
# 1  /content/zoobot/data/demo_rings/images/287521/...
# 2  /content/zoobot/data/demo_rings/images/519986/...
# 3  /content/zoobot/data/demo_rings/images/362959/...
# 4  /content/zoobot/data/demo_rings/images/426137/...

# %% [markdown]
# Wondering about "label_cols"?
#
# This is a list of catalog columns which should be used as labels
#
# Here,`label_cols = ['ring']`

# %% [markdown]
# For binary classification, the label column should have binary (0 or 1) labels for your classes.
#
# To support more complicated labels, Zoobot expects a list of columns. A list with one element works fine.

# %% [markdown]
# ## Configure Finetuning

# %%
import pandas as pd

from zoobot.pytorch.training import finetune
from galaxy_datasets.pytorch.galaxy_datamodule import GalaxyDataModule
# Out:
# GZDESI/GZRings/GZCD not available from galaxy_datasets.pytorch.datasets - skipping

# %%
# TODO you can update these paths to suit own data
checkpoint_loc = os.path.join(zoobot_dir, 'data/pretrained_models/pytorch/checkpoint.ckpt')  # downloaded above
save_dir = os.path.join(zoobot_dir, 'results/pytorch/finetune/finetune_binary_classification')

# %%
label_col = 'ring'  # name of column in catalog with binary (0 or 1) labels for your classes
label_cols = [label_col]  # To support more complicated labels, Zoobot expects a list of columns. A list with one element works fine.

# %%
train_catalog[label_col] = train_catalog[label_col].astype(int)

# %%
train_catalog[label_col]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 795    0
# 796    1
# 797    0
# 798    1
# 799    0
# Name: ring, Length: 800, dtype: int64

# %%
datamodule = GalaxyDataModule(
  label_cols=label_cols,
  catalog=train_catalog,
  batch_size=32,
  resize_after_crop=224,  # the size of the images input to the model
  num_workers=2  # sets the parallelism for loading data. 2 works well on colab.
)

# %% [markdown]
# ## Check Images Load
#
# Optional - check that all images load correctly.
#
# Worth checking once, and especially if you get "InvalidArgumentError" when running the model below.

# %%
assert all([os.path.isfile(loc) for loc in train_catalog['file_loc']])

# %% [markdown]
# # Now the Actual Finetuning

# %%
model = finetune.FinetuneableZoobotClassifier(
  checkpoint_loc=checkpoint_loc,
  num_classes=2,
  n_blocks=2  # only updating the head weights. Set 0 for only output layer. Set e.g. 1, 2 to finetune deeper.
)
# don't worry about any "automatically upgraded" INFO message below

# %%
trainer = finetune.get_trainer(save_dir, accelerator='auto', devices='auto', max_epochs=30)
trainer.fit(model, datamodule)
# should reach about 85% accuracy, loss of about 0.4
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# WARNING:pytorch_lightning.loggers.tensorboard:Missing logger folder: /content/zoobot/lightning_logs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name              | Type             | Params
# -------------------------------------------------------
# 0 | encoder           | EfficientNet     | 4.0 M
# 1 | train_loss_metric | MeanMetric       | 0
# 2 | val_loss_metric   | MeanMetric       | 0
# 3 | test_loss_metric  | MeanMetric       | 0
# 4 | head              | LinearClassifier | 2.6 K
# 5 | train_acc         | BinaryAccuracy   | 0
# 6 | val_acc           | BinaryAccuracy   | 0
# 7 | test_acc          | BinaryAccuracy   | 0
# -------------------------------------------------------
# 4.0 M     Trainable params
# 0         Non-trainable params
# 4.0 M     Total params
# 16.038    Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (17) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 0, global step 17: 'finetuning/val_loss' reached 0.69405 (best 0.69405), saving model to '/content/zoobot/results/pytorch/finetune/finetune_binary_classification/checkpoints/0.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 1, global step 34: 'finetuning/val_loss' reached 0.69309 (best 0.69309), saving model to '/content/zoobot/results/pytorch/finetune/finetune_binary_classification/checkpoints/1.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 2, global step 51: 'finetuning/val_loss' reached 0.68850 (best 0.68850), saving model to '/content/zoobot/results/pytorch/finetune/finetune_binary_classification/checkpoints/2.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 3, global step 68: 'finetuning/val_loss' reached 0.67980 (best 0.67980), saving model to '/content/zoobot/results/pytorch/finetune/finetune_binary_classification/checkpoints/3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 4, global step 85: 'finetuning/val_loss' reached 0.65104 (best 0.65104), saving model to '/content/zoobot/results/pytorch/finetune/finetune_binary_classification/checkpoints/4.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 5, global step 102: 'finetuning/val_loss' reached 0.61634 (best 0.61634), saving model to '/content/zoobot/results/pytorch/finetune/finetune_binary_classification/checkpoints/5.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 6, global step 119: 'finetuning/val_loss' reached 0.59161 (best 0.59161), saving model to '/content/zoobot/results/pytorch/finetune/finetune_binary_classification/checkpoints/6.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 7, global step 136: 'finetuning/val_loss' reached 0.55420 (best 0.55420), saving model to '/content/zoobot/results/pytorch/finetune/finetune_binary_classification/checkpoints/7.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 8, global step 153: 'finetuning/val_loss' reached 0.52661 (best 0.52661), saving model to '/content/zoobot/results/pytorch/finetune/finetune_binary_classification/checkpoints/8.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 9, global step 170: 'finetuning/val_loss' reached 0.48252 (best 0.48252), saving model to '/content/zoobot/results/pytorch/finetune/finetune_binary_classification/checkpoints/9.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 10, global step 187: 'finetuning/val_loss' reached 0.44209 (best 0.44209), saving model to '/content/zoobot/results/pytorch/finetune/finetune_binary_classification/checkpoints/10.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 11, global step 204: 'finetuning/val_loss' reached 0.40953 (best 0.40953), saving model to '/content/zoobot/results/pytorch/finetune/finetune_binary_classification/checkpoints/11.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 12, global step 221: 'finetuning/val_loss' reached 0.37934 (best 0.37934), saving model to '/content/zoobot/results/pytorch/finetune/finetune_binary_classification/checkpoints/12.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 13, global step 238: 'finetuning/val_loss' reached 0.36052 (best 0.36052), saving model to '/content/zoobot/results/pytorch/finetune/finetune_binary_classification/checkpoints/13.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 14, global step 255: 'finetuning/val_loss' reached 0.33722 (best 0.33722), saving model to '/content/zoobot/results/pytorch/finetune/finetune_binary_classification/checkpoints/14.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 15, global step 272: 'finetuning/val_loss' reached 0.32168 (best 0.32168), saving model to '/content/zoobot/results/pytorch/finetune/finetune_binary_classification/checkpoints/15.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 16, global step 289: 'finetuning/val_loss' reached 0.32150 (best 0.32150), saving model to '/content/zoobot/results/pytorch/finetune/finetune_binary_classification/checkpoints/16.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 17, global step 306: 'finetuning/val_loss' reached 0.30287 (best 0.30287), saving model to '/content/zoobot/results/pytorch/finetune/finetune_binary_classification/checkpoints/17.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 18, global step 323: 'finetuning/val_loss' reached 0.29626 (best 0.29626), saving model to '/content/zoobot/results/pytorch/finetune/finetune_binary_classification/checkpoints/18.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 19, global step 340: 'finetuning/val_loss' reached 0.29523 (best 0.29523), saving model to '/content/zoobot/results/pytorch/finetune/finetune_binary_classification/checkpoints/19.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 20, global step 357: 'finetuning/val_loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 21, global step 374: 'finetuning/val_loss' reached 0.29137 (best 0.29137), saving model to '/content/zoobot/results/pytorch/finetune/finetune_binary_classification/checkpoints/21.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 22, global step 391: 'finetuning/val_loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 23, global step 408: 'finetuning/val_loss' reached 0.28795 (best 0.28795), saving model to '/content/zoobot/results/pytorch/finetune/finetune_binary_classification/checkpoints/23.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 24, global step 425: 'finetuning/val_loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 25, global step 442: 'finetuning/val_loss' reached 0.27936 (best 0.27936), saving model to '/content/zoobot/results/pytorch/finetune/finetune_binary_classification/checkpoints/25.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 26, global step 459: 'finetuning/val_loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 27, global step 476: 'finetuning/val_loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 28, global step 493: 'finetuning/val_loss' was not in top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Epoch 29, global step 510: 'finetuning/val_loss' reached 0.26290 (best 0.26290), saving model to '/content/zoobot/results/pytorch/finetune/finetune_binary_classification/checkpoints/29.ckpt' as top 1
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=30` reached.

# %%
# now we can load the best checkpoint and make predictions
best_checkpoint = trainer.checkpoint_callback.best_model_path
finetuned_model = finetune.FinetuneableZoobotClassifier.load_from_checkpoint(best_checkpoint)

# %%
from zoobot.pytorch.predictions import predict_on_catalog

predict_on_catalog.predict(
  test_catalog,
  finetuned_model,
  n_samples=1,
  label_cols=['not_ring', 'ring'],  # it's a quick of the current code that it always makes 2D predictions. For binary, [no, yes]. I might change this.
  save_loc=os.path.join(save_dir, 'finetuned_predictions.csv'),
  trainer_kwargs={'accelerator': 'gpu'},
  datamodule_kwargs={'num_workers': 2, 'batch_size': 32}
)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]

# %% [markdown]
# Let's quickly check if they're any good:

# %%
predictions = pd.read_csv(os.path.join(save_dir, 'finetuned_predictions.csv'))
predictions.head()
# Out:
#         id_str  not_ring_pred  ring_pred
# 0  453526_3245       0.006878   0.993121
# 1  127202_5277       0.101156   0.898844
# 2   469597_327       0.955056   0.044944
# 3  433105_1762       0.989069   0.010931
# 4   52497_3109       0.239535   0.760465

# %%
predictions = pd.merge(predictions, test_catalog[['id_str', 'file_loc', 'ring']])
predictions.head()
# Out:
#         id_str  not_ring_pred  ring_pred  \
# 0  453526_3245       0.006878   0.993121
# 1  127202_5277       0.101156   0.898844
# 2   469597_327       0.955056   0.044944
# 3  433105_1762       0.989069   0.010931
# 4   52497_3109       0.239535   0.760465
#
#                                             file_loc   ring
# 0  /content/zoobot/data/demo_rings/images/453526/...   True
# 1  /content/zoobot/data/demo_rings/images/127202/...   True
# 2  /content/zoobot/data/demo_rings/images/469597/...  False
# 3  /content/zoobot/data/demo_rings/images/433105/...  False
# 4  /content/zoobot/data/demo_rings/images/52497/5...   True

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

def show_rings(df):
  # little utility function to visualise galaxies and our ring labels/predictions

  fig, axes = plt.subplots(ncols=5, figsize=(16, 3))
  for n in range(5):
    galaxy = df.iloc[n]

    im = Image.open(galaxy['file_loc'])
    axes[n].imshow(im)

    correct = np.around(galaxy['ring_pred']) == galaxy['ring']
    if correct:
      color = 'g'
    else:
      color = 'r'
    axes[n].text(20, 50, 'Pred: {:.2f}'.format(galaxy['ring_pred']), color=color)
    axes[n].text(20, 90, 'Label: {}'.format(galaxy['ring']), color=color)

    axes[n].axis('off')

# %%
top_5_predictions = predictions.sort_values('ring_pred', ascending=False)
show_rings(top_5_predictions)
print(top_5_predictions['id_str'])
# Out:
# 72     297531_4326
# 89     496174_1981
# 86      498880_985
# 114     320199_672
# 50     496393_4172
#           ...
# 94      494983_983
# 15     329088_5754
# 33     333252_2098
# 77     326911_5263
# 6        458851_85
# Name: id_str, Length: 200, dtype: object

# %%
bottom_5_predictions = predictions.sort_values('ring_pred', ascending=True)
show_rings(bottom_5_predictions)

# %%
random_predictions = predictions.sample(5)
print(random_predictions['id_str'])
show_rings(random_predictions)
# Out:
# 65     424255_1381
# 120    440062_1965
# 183    354313_2098
# 57     348565_3693
# 157    493765_2349
# Name: id_str, dtype: object

# %% [markdown]
# Pretty good given only a couple of hundred examples for each class.

# %%
train_catalog[label_col].value_counts()
# Out:
# 0    427
# 1    373
# Name: ring, dtype: int64
